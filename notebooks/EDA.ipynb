# %%
import os
import pandas as pd

# %%
path = os.path.join('..','dados','Embasa_sem_duplicidade.xlsx')
df_processos = pd.read_excel(path)

# %%
df_processos
# Out:
#                          processo            cpf_cnpj data_inicio_processo  \
# 0       0002153-53.2010.5.05.0531  13.504.675/0001-10           0010-10-04
# 1       0000082-80.1983.8.05.0141  13.504.675/0001-10           1983-07-25
# 2       0008104-82.2010.8.05.0141  13.504.675/0001-10           1983-07-25
# 3       0000082-98.1985.8.05.0274  13.504.675/0001-10           1985-10-28
# 4       0009540-51.1986.8.05.0001  13.504.675/0001-10           1986-05-08
# ...                           ...                 ...                  ...
# 110012  0004034-83.2025.8.05.0080  13.504.675/0001-10           2025-02-07
# 110013  0000168-86.2025.8.05.0106  13.504.675/0001-10           2025-02-07
# 110014  0023080-04.2025.8.05.0001  13.504.675/0001-10           2025-02-07
# 110015  0000667-49.2025.5.05.0000  13.504.675/0001-10           2025-02-07
# 110016  0000676-11.2025.5.05.0000  13.504.675/0001-10           2025-02-07
#
#        data_ultima_movimentação data_ultima_verificação  \
# ...
